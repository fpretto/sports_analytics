# %%
import sys
import random
import time
import cv2 as cv2
import numpy as np
from datetime import datetime
from keras.models import load_model
from imutils.video import VideoStream, FPS
from shapely.geometry import Point, Polygon
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import matplotlib.pyplot as plt
import imutils
import importlib
import pickle as pkl

#path_model = '/home/deeplearningcv/Ludis/Repo/Ludis/Squash/03 - Player Detection/'
path_model = 'C:/Repo/Ludis/Squash/04 - Player Identification/'
sys.path.insert(0, path_model)
import YOLOv3_mod as yolo3

#path_model = 'C:/Repo/Ludis/Squash/03 - Player Detection/'
#sys.path.insert(0, path_model)
#import YOLOv3 as yolo3

importlib.reload(yolo3)
# Out:
# <module 'YOLOv3_mod' from 'C:/Repo/Ludis/Squash/04 - Player Identification\\YOLOv3_mod.py'>

# %% [markdown]
# ### Definicion Paths

# %%
root = 'C:/GoogleDrive/'
path_court = root + 'LudisAI/05 - Court Mapping/'
path_dataset = root + 'LudisAI/00 - Datasets/'

# %% [markdown]
# ### Instanciar el modelo y parametros

# %%
yolo_model = load_model(root + '/LudisAI/03 - Player Detection and Tracking/' + 'yolo_model.h5')

net_h, net_w = 416, 416
obj_thresh, nms_thresh = 0.5, 0.45
anchors = [[116,90,  156,198,  373,326],  [30,61, 62,45,  59,119], [10,13,  16,30,  33,23]]
labels = ["person"]
# Out:
# C:\Users\fabri\Anaconda3\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [markdown]
# ### Definicion de coordenadas de la cancha

# %%
## Definicion de Coordenadas Court e Image

src_pts = np.array([
        [275,310],    # Drop izquierdo
        [215,420],    # Cuadrado de saque izquierdo superior
        [154,536],    # Fondo izquierdo
        [478,536],    # Puerta
        [802,536],    # Fondo derecho
        [748,419],    # Cuadrado de saque derecho superior 
        [700,310]     # Drop derecho
    ])

# Four corners of the court + mid-court circle point in destination image 
# Start top-left corner and go anti-clock wise + mid-court circle point
dst_pts = np.array([
      [1,  1],      # Drop izquierdo
      [1,  349],    # Cuadrado de saque izquierdo superior
      [1,  654],    # Fondo izquierdo
      [209,  654],  # Puerta
      [412, 654],   # Fondo derecho
      [412, 349],   # Cuadrado de saque derecho superior 
      [412, 1]      # Drop derecho
    ])

# %% [markdown]
# ### Definicion Helpers

# %%
# Use the boxes info from the tensor prediction result
#
# x1,y1 ------
# |          |
# |          |
# |          |
# --------x2,y2
#

def drawPlayers(im, pred_boxes, pred_classes, showResult=False):
    
    color = [255, 0, 0]
    thickness = 3
    radius = 3

    i  = 0
    for box in pred_boxes:

        # Include only class Person
        #if pred_classes[i] == 'Person':  

        x1 = int(box.xmin)
        y1 = int(box.ymin)
        x2 = int(box.xmax)
        y2 = int(box.ymax)

        xc = x1 + int((x2 - x1)/2)
        player_pos = (xc - 1, y2 - 25)

        court = Polygon(src_pts)

        # Draw only players that are within the court
        if (box.classes[0] > obj_thresh) & (Point(player_pos).within(court)):
            if showResult:
                print("[% 3d, % 3d]" %(xc, y2))

            cv2.circle(im, player_pos, radius, color, thickness)
            i = i + 1            

    if showResult:
        cv2.imshow('Court', im)
        #cv2.imshow('Court', im_poly)
        
        k = cv2.waitKey(0)
        if k == 27:
            cv2.destroyAllWindows()

def homographyTransform(img_src, img_dst, showResult=False):

    # Calculate Homography
    h, status = cv2.findHomography(src_pts, dst_pts)
    img_out = cv2.warpPerspective(img_src, h, (img_dst.shape[1], img_dst.shape[0]))

    if showResult:
        cv2.imshow('Court', img_out)
        
        k = cv2.waitKey(0)
        if k == 27:
            cv2.destroyAllWindows()

    return img_out

def getPlayersMask(im):
    lower_range = np.array([255,0,0])                         # Set the Lower range value of blue in BGR
    upper_range = np.array([255,155,155])                     # Set the Upper range value of blue in BGR
    mask = cv2.inRange(im, lower_range, upper_range)          # Create a mask with range
    result = cv2.bitwise_and(im, im, mask = mask)             # Performing bitwise and operation with mask in img variable
    # cv2_imshow(result)                              

    return cv2.inRange(result, lower_range, upper_range)  

def drawPlayersOnCourt(im, coord, color, radius=10):
    for pos in coord:
        center_coordinates = (pos[0], pos[1])
        cv2.circle(im, center_coordinates, radius, color, thickness=-1) 

    return im

# %% [markdown]
# ### Image Court Mapping

# %% [markdown]
# #### Court

# %%
## Court
img_court = cv2.imread(path_court + 'squash_court.jpg')
cv2.imshow('Court', img_court)

k = cv2.waitKey(0)
if k == 27:
    cv2.destroyAllWindows()

# %%
#cv2.polylines(img_court, [dst_pts], isClosed=True, color=[255,0,0], thickness=2)
#cv2.imshow('Court', img_court)

#k = cv2.waitKey(0)
#if k == 27:
#    cv2.destroyAllWindows()

# %% [markdown]
# #### Image

# %%
## Image
cap = cv2.VideoCapture(path_dataset + 'test_videos/squash-trim.avi')

cap.set(1, 1)

ret, frame = cap.read()

scale_percent = 50 # percent of original size
width = int(frame.shape[1] * scale_percent / 100)
height = int(frame.shape[0] * scale_percent / 100)
dim = (width, height) 

image = cv2.resize(frame, dim, interpolation = cv2.INTER_AREA)
cv2.imshow('Frame 1', image)

k = cv2.waitKey(0)
if k == 27:
    cv2.destroyAllWindows()

# %%
# Four corners of the 3D court 
# Start top-left corner and go anti-clock wise 

im_poly = image.copy()

# cv2.fillPoly(img_src, [src_pts], 255)
cv2.polylines(im_poly, [src_pts], isClosed=True, color=[0,255,255], thickness=2)

cv2.imshow('Court', im_poly)

k = cv2.waitKey(0)
if k == 27:
    cv2.destroyAllWindows()

# %% [markdown]
# #### Modelo

# %%
## Diccionario para guardar labels y coords de los jugadores
dictPlayers = {'player_A': {'label': 'Player A', 'player_coords': [], 'player_torso': [], 'tracking_coords': []},
               'player_B': {'label': 'Player B', 'player_coords': [], 'player_torso': [], 'tracking_coords': []}}

# %%
frame_n = 1

image_h, image_w, _ = image.shape
new_image = yolo3.preprocess_input(image, net_h, net_w)

# run the prediction
yolos = yolo_model.predict(new_image)
boxes = []

for i in range(len(yolos)):
    # decode the output of the network
    boxes += yolo3.decode_netout(yolos[i][0], anchors[i], obj_thresh, nms_thresh, net_h, net_w)
    
# correct the sizes of the bounding boxes
yolo3.correct_yolo_boxes(boxes, image_h, image_w, net_h, net_w)

# suppress non-maximal boxes
yolo3.do_nms(boxes, nms_thresh)  

# draw bounding boxes on the image using labels
image = yolo3.draw_boxes(image, frame, frame_n, boxes, labels, obj_thresh, src_pts, 
                                 dictPlayers, player=dictPlayers['player_A']['label'])

# %%
username = 'Nick Matthew'
dictPlayers['player_A']['label'] = username

# %%
## Show Boxes
cv2.imshow('Boxes', image)

k = cv2.waitKey(0)
if k == 27:
    cv2.destroyAllWindows()

# %%
players['player_2']['coords']

# %%
## Draw Boxes on Image
drawPlayers(image, boxes, labels, showResult=True)

# %%
## Homography Transform
img_out = homographyTransform(image, img_court, True)

# %%
## Players Mask
mask = getPlayersMask(img_out)    
cv2.imshow('Court', img_out)

k = cv2.waitKey(0)
if k == 27:
    cv2.destroyAllWindows()

# %%
# Get the contours from the players "dots" so we can reduce the coordinates
# to the number of players on the court.
cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)

color = [255, 0, 0]   

if cnts is not None:      
    for cnt in cnts:
        result = drawPlayersOnCourt(img_court, cnt[0], color)

cv2.imshow('Court', result)

k = cv2.waitKey(0)
if k == 27:
    cv2.destroyAllWindows()

# %% [markdown]
# ### Video Court Mapping

# %%
## Diccionario para guardar labels y coords de los jugadores
dictPlayers = {'player_A': {'label': 'Player A', 'player_coords': [], 'player_torso': [], 'tracking_coords': []},
               'player_B': {'label': 'Player B', 'player_coords': [], 'player_torso': [], 'tracking_coords': []}}

# %%
video_input  = path_dataset + "test_videos/squash-trim.avi"
video_output = root + 'LudisAI/04 - Player Identification/squash-trim_playerId_cos_sim_6pts.avi'

# %%
from datetime import datetime
from time import sleep
from collections import deque
import imutils

cap = cv2.VideoCapture(video_input)

video_FourCC = int(cap.get(cv2.CAP_PROP_FOURCC))
video_fps    = int(cap.get(cv2.CAP_PROP_FPS))
video_size   = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
totalFrames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
video_duration = totalFrames / video_fps

corte = int(totalFrames*0.25)

currentFrame = 0
start_time = datetime.now()
writer = None
grabbed = True
deciles = [int(x) for x in np.linspace(0,1,11)*totalFrames]

scale_percent = 50 # percent of original size
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) * scale_percent / 100)
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) * scale_percent / 100)
dim = (width, height) 

writer = cv2.VideoWriter(video_output, video_FourCC, video_fps, dim)

court_img = cv2.imread(path_court + 'squash_court.jpg')

blue_color = (255,0,0)
red_color = (0,0,255)

coords = []
frame_n = 0

# loop over frames from the video file stream (207)
while grabbed:     
    frame_n += 1
    #print(frame_n)
    if frame_n == 1:
        print(frame_n)
    # read the next frame from the file
    grabbed, frame = cap.read()

    if grabbed:
        
####### Reescalo el frame porque las coords de la cancha en el video estan en esta escala
        frame_orig = frame.copy()
        frame = cv2.resize(frame, dim, interpolation = cv2.INTER_AREA)

####### Get player positions
        frame_h, frame_w, _ = frame.shape
        new_frame = yolo3.preprocess_input(frame, net_h, net_w)

        # run the prediction
        yolos = yolo_model.predict(new_frame)
        boxes = []

        for i in range(len(yolos)):
            # decode the output of the network
            boxes += yolo3.decode_netout(yolos[i][0], anchors[i], obj_thresh, nms_thresh, net_h, net_w)

        # correct the sizes of the bounding boxes
        yolo3.correct_yolo_boxes(boxes, frame_h, frame_w, net_h, net_w)

        # suppress non-maximal boxes
        yolo3.do_nms(boxes, nms_thresh)

        # draw bounding boxes on the image using labels
        
        # version original
        #yolo3.draw_boxes(frame, boxes, labels, obj_thresh)
        
        # version mod - player identification
        frame = yolo3.draw_boxes(frame, frame_n, boxes, labels, obj_thresh, src_pts, 
                                 dictPlayers, player=dictPlayers['player_A']['label'])
   
        #cv2.imshow("Objet Detection YOLO", frame)
        # write the output frame to disk
        writer.write(frame)
        
        if frame_n in deciles:
            print('Processed frames: {} de {} ({}%)'.format(frame_n, totalFrames, np.round(frame_n*100/totalFrames, 0)))
              
    else:
        grabbed = False
            

# cv2_imshow(result)
    
writer.release()
cap.release()
cv2.destroyAllWindows()

pkl.dump(dictPlayers, open(root + 'LudisAI/04 - Player Identification/coords_playerId_cos_sim_6pts.pkl', 'wb'))

duration = datetime.now()-start_time
print("[INFO] process took {} seconds".format(duration))

print("Video created")
# Out:
# 1
# Processed frames: 233 de 2334 (10.0%)
# Processed frames: 466 de 2334 (20.0%)
# Processed frames: 700 de 2334 (30.0%)
# Processed frames: 933 de 2334 (40.0%)
# Processed frames: 1167 de 2334 (50.0%)
# Processed frames: 1400 de 2334 (60.0%)
# Processed frames: 1633 de 2334 (70.0%)
# Processed frames: 1867 de 2334 (80.0%)
# Processed frames: 2100 de 2334 (90.0%)
# [INFO] process took 2:11:14.032044 seconds
# Video created

# %% [markdown]
# ### Pruebas

# %%
## Image
cap = cv2.VideoCapture(path_dataset + 'test_videos/squash-trim.avi')
dictPlayers = pkl.load(open(root + 'LudisAI/04 - Player Identification/coords_playerId_6pts.pkl', 'rb'))
nro = 1

cap.set(1, nro)

ret, frame = cap.read()

scale_percent = 50 # percent of original size
width = int(frame.shape[1] * scale_percent / 100)
height = int(frame.shape[0] * scale_percent / 100)
dim = (width, height) 

#image = cv2.resize(frame, dim, interpolation = cv2.INTER_AREA)

for coord in dictPlayers['player_A']['tracking_coords'][nro]:
    cv2.circle(image, coord, 3, [255,0,0], 3)

torsoA = (dictPlayers['player_A']['tracking_coords'][nro][2][0], 
          int(dictPlayers['player_A']['tracking_coords'][nro][4][1] + \
          (dictPlayers['player_A']['tracking_coords'][nro][2][1]-dictPlayers['player_A']['tracking_coords'][nro][4][1])/2))

torsoAcolor = [int(x) for x in list(frame[torsoA])]
cv2.circle(image, (50,50), 3, [torsoAcolor[2],torsoAcolor[1],torsoAcolor[0]], 3)

cv2.circle(image, torsoA, 3, torsoAcolor, 3)



for coord in dictPlayers['player_B']['tracking_coords'][nro]:
    cv2.circle(image, coord, 3, [0,255,0], 3)

torsoB = (dictPlayers['player_B']['tracking_coords'][nro][2][0], 
          int(dictPlayers['player_B']['tracking_coords'][nro][4][1] + \
          (dictPlayers['player_B']['tracking_coords'][nro][2][1]-dictPlayers['player_B']['tracking_coords'][nro][4][1])/2))

torsoBcolor = [int(x) for x in list(frame[torsoB])]
cv2.circle(image, torsoB, 3, torsoBcolor, 3)
cv2.circle(image, (50,70), 3, [torsoBcolor[2],torsoBcolor[1],torsoBcolor[0]], 3)

cv2.imshow('Frame 1', image)

k = cv2.waitKey(0)
if k == 27:
    cv2.destroyAllWindows()

# %%
print(len(dictPlayers['player_A']['player_coords']))
print(len(dictPlayers['player_B']['player_coords']))
# Out:
# 1832
# 2601

# %%
list_diff = [(x1[0]-x0[0], x1[1]-x0[1]) for x0, x1 in zip(dictPlayers['player_A']['player_coords'][0::], dictPlayers['player_A']['player_coords'][1::])]
list_dist = [np.sqrt(x**2 + y**2) for x, y in list_diff]

# %%
np.sum(list_dist) * 0.0002645833
# Out:
# 5.062515375594593

# %%
def create_heatmap(coords, player, video_duration, bins=25):
    
    ## Distance and Speed calculation
    pix2meter = 0.0002645833
    list_diff = [(x1[0]-x0[0], x1[1]-x0[1]) for x0, x1 in zip(coords[0::], coords[1::])] # Calculo diferencia en posiciones
    list_dist = [np.sqrt(x**2 + y**2) for x, y in list_diff] # Calculo distancia Euclidea
    distTraveled = int(np.sum(list_dist) * pix2meter)
    speed = np.round((distTraveled / video_duration) * 3600/1000, 1)
    
    ## Heatmap plot
    court = cv2.imread(path_court + 'squash_court.jpg')
    
    pos_x = [pos[0] for pos in coords]
    pos_y = [pos[1] for pos in coords]
    heatmap, xedges, yedges = np.histogram2d(pos_x, pos_y, bins=bins,normed=True)
    extent = [0, court.shape[1], court.shape[0], 0]
    
    fig, ax = plt.subplots(1, 1, figsize=(10, 10))
    ax.set_xlim(0, court.shape[1])
    ax.set_ylim(court.shape[0], 0)
    
    im1 = ax.imshow(court[:,:,[2,1,0]])

    im2 = ax.imshow(heatmap.T, cmap='hot_r', alpha=0.8, interpolation='gaussian', extent=extent)
              #extent=[xedges.min(), xedges.max(), yedges.max(), yedges.min()])

    plt.axis('off')
    #plt.title(f'Heatmap: Player {idx}',fontsize=15)
    plt.title(f'Heatmap: {player}',fontsize=15)
    plt.annotate(f'Court Coverage: {distTraveled} meters',(.19,.1),xycoords='figure fraction',fontsize=12)
    plt.annotate(f'Speed: {speed} km/h',(.19,.08),xycoords='figure fraction',fontsize=12)
    plt.show()

# %%
dictPlayers = pkl.load(open(root + 'LudisAI/04 - Player Identification/coords_playerId_cos_sim.pkl', 'rb'))

# %%
create_heatmap(dictPlayers['player_A']['player_coords'], dictPlayers['player_A']['label'], video_duration, bins=15)

# %%
create_heatmap(dictPlayers['player_B']['player_coords'], dictPlayers['player_B']['label'], video_duration, bins=15)
